# %%
# !pip3 install synapseclient
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 218.3/218.3 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.1/143.1 kB 23.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 14.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 kB 8.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.3
#     Uninstalling urllib3-2.0.3:
#       Successfully uninstalled urllib3-2.0.3
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 6.6.0
#     Uninstalling importlib-metadata-6.6.0:
#       Successfully uninstalled importlib-metadata-6.6.0
# ...

# %%
import synapseclient
from synapseclient import Activity
from synapseclient import Entity, Project, Folder, File, Link
from synapseclient import Evaluation, Submission, SubmissionStatus
from synapseclient import Wiki
from synapseclient import Schema, Column, Table, Row, RowSet, as_table_columns


syn = synapseclient.Synapse()

# You need to login first. Replace '...' with your Synapse access token.
syn.login(authToken='eyJ0eXAiOiJKV1QiLCJraWQiOiJXN05OOldMSlQ6SjVSSzpMN1RMOlQ3TDc6M1ZYNjpKRU9VOjY0NFI6VTNJWDo1S1oyOjdaQ0s6RlBUSCIsImFsZyI6IlJTMjU2In0..HNRG3hx28x2O7KUN7mVjow5U770WB_vy7Zo8tKN0bJYA5Yy63vZXtUlsfwUCJAwbjYhpzYVYE4mMJ8PHWr2IJyxakZCJ4GzoFbqfbmzvRLwDNEuGqryM0eLUdxutxfvtsooX2cK8iGUYdRJnnujuWjPlwtcgkIA4vBypJ5C78cRLyQ8YI_BceEhjzYVaAq1m8sJM0yrtN3cHIvHftFm2K64Uiic8nsvhiZKBVgmJ0fGermOuAtnULA721ijKar4AUwq8GpBchEtZT5veO-LH0YiWpHsvGTC9Z1LI8XG88KPz36r2Pmr-3VDEaCvhfFVrGSoCfEXVHtGuj3nH4avrXw')

# Replace 'syn52190581' with your actual Synapse File ID (pick one).
synapse_id = 'syn52228342'
entity = syn.get(synapse_id)

print(entity)
# Out:
# Welcome, nimbusboconnor!
#
# File: rna_seq_1.cram (syn52228342)
#   md5=b026324c6904b2a9cb4b88d6d61c81d1
#   fileSize=2
#   contentType=application/octet-stream
#   externalURL=None
#   cacheDir=/home/jovyan/.synapseCache/163/127538163
#   files=['rna_seq_1.cram']
#   path=/home/jovyan/.synapseCache/163/127538163/rna_seq_1.cram
#   synapseStore=True
# properties:
#   concreteType=org.sagebionetworks.repo.model.FileEntity
#   createdBy=3477459
#   createdOn=2023-08-02T04:43:23.353Z
#   dataFileHandleId=127538163
#   etag=fd29ffdc-710a-4bb4-b32a-24ccc19769e1
#   id=syn52228342
#   isLatestVersion=True
#   modifiedBy=3477459
#   modifiedOn=2023-08-02T05:11:25.681Z
#   name=rna_seq_1.cram
#   parentId=syn52228335
#   versionLabel=1
#   versionNumber=1
# annotations:
#   data_type=['rnaseq']
#   species=['mouse']

# %%
# !echo 'hi there, this is a fake cram file' > rna_seq_7.cram

# %%
project_entity = syn.get('syn52228335')

print (project_entity)

test_file = File('rna_seq_7.cram', description='A sample fake cram file', parent=project_entity, species='human', data_type='rnaseq')
test_file = syn.store(test_file)

print (test_file)
# Out:
# Project: Test Project 20230801 (syn52228335)
# properties:
#   concreteType=org.sagebionetworks.repo.model.Project
#   createdBy=3477459
#   createdOn=2023-08-02T04:34:19.567Z
#   etag=6fda1855-e043-4e9e-b523-618003451cb3
#   id=syn52228335
#   modifiedBy=3477459
#   modifiedOn=2023-08-02T04:52:47.435Z
#   name=Test Project 20230801
#   parentId=syn4489
# annotations:
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# File: rna_seq_7.cram (syn52228694)
#   md5=ae394ed4ab683caab778aa1495067781
#   fileSize=35
#   contentType=application/octet-stream
#   externalURL=None
#   cacheDir=
#   files=['rna_seq_7.cram']
#   path=rna_seq_7.cram
#   synapseStore=True
# properties:
#   concreteType=org.sagebionetworks.repo.model.FileEntity
#   createdBy=3477459
#   createdOn=2023-08-02T06:05:33.302Z
#   dataFileHandleId=127538836
#   description=A sample fake cram file
# ...

# %%
# download file into current working directory
entity = syn.get('syn52228350', downloadLocation='.', version='1')
print(entity.name)
print(entity.path)

# now let's print that content out
with open(entity.path, 'r') as file:
    content = file.read()
print(content)
# Out:
# wgs_4.cram
# /home/jovyan/wgs_4.cram
# 4

# %%
import os.path

data = [[3, "human", "rna_seq", "syn52214733"],
            [4, "mouse", "wgs", "syn52190582"]]

# get the table schema
schema = syn.get('syn52228395')
print (schema)

# now store
row_reference_set = syn.store(RowSet(schema=schema, rows=[Row(r) for r in data]))
# Out:
# Schema: test_table (syn52228395)
#   columns_to_store=[]
# properties:
#   columnIds=['195773', '195774', '195775', '195776']
#   concreteType=org.sagebionetworks.repo.model.table.TableEntity
#   createdBy=3477459
#   createdOn=2023-08-02T05:02:19.815Z
#   etag=f7b00368-70f2-45da-ab0b-6c441ec32a39
#   id=syn52228395
#   isLatestVersion=True
#   modifiedBy=3477459
#   modifiedOn=2023-08-02T05:03:12.014Z
#   name=test_table
#   parentId=syn52228335
#   versionComment=in progress
#   versionLabel=in progress
#   versionNumber=2
# annotations:

# %%
# !pip3 install pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 26.7 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 38.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 29.5 MB/s eta 0:00:0000:0100:01
# ...

# %%
import pandas as pd

query_results = syn.tableQuery('SELECT * FROM syn52228395')
df = query_results.asDataFrame()
print(df)
# Out:
# [WARNING] /srv/conda/envs/notebook/lib/python3.10/site-packages/synapseclient/table.py:595: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   df = pd.read_csv(filepath,
#      my_id species data_type         file
# 1_1      1   mouse   rna_seq  syn52190586
# 2_1      2   human       wgs  syn52190584
# 3_2      3   human   rna_seq  syn52214733
# 4_2      4   mouse       wgs  syn52190582
